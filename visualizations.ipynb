# %% [markdown]
# # Optoelektronika :C

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('datasets/LED_PD_UpdF_UpdR_02112022/IpdF_UpdF_2022-12-02_16-24-39_0.csv', sep=',', skiprows=3)

#print(dataset)

# %% [markdown]
# # Directory /LED_PD_UpdF_UpdR_02112022

# %% [markdown]
# ## Photodiode forward voltage versus forward current

# %%
plt.figure()
dataset['Get Measurement Value']=dataset['Get Measurement Value'] * 1000 # to convert to mA
dataset.plot(x='Get Measurement Value.1', y='Get Measurement Value')
plt.grid()
plt.xlabel('Voltage [V]')
plt.ylabel('Current [mA]')

plt.show()

# %%
dataset=pd.read_csv('datasets/LED_PD_UpdF_UpdR_02112022/IpdR_UpdR 2022-12-02 15-57-44 0.csv', sep=',', skiprows=3)

print(dataset)
# Out:
#                         Time  Step  Set CH1 On/Off  Set CH2 On/Off  \
# 0    2022-12-02 15:44:21.131     1             1.0             NaN
# 1    2022-12-02 15:44:22.557     2             NaN             1.0
# 2    2022-12-02 15:44:27.277     3             NaN             NaN
# 3    2022-12-02 15:44:29.423     4             NaN             NaN
# 4    2022-12-02 15:44:31.667     5             NaN             NaN
# ..                       ...   ...             ...             ...
# 293  2022-12-02 15:55:37.127   294             NaN             NaN
# 294  2022-12-02 15:55:39.234   295             NaN             NaN
# 295  2022-12-02 15:55:41.480   296             NaN             NaN
# 296  2022-12-02 15:55:42.891   297             NaN             NaN
# 297  2022-12-02 15:55:44.300   298             NaN             NaN
#
#      Sweep CH2 Voltage Setting  Get CH2 Voltage Setting  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          0.0                      0.0
# 3                          0.0                      NaN
# 4                          0.0                      NaN
# ..                         ...                      ...
# 293                        6.0                      NaN
# 294                        6.0                      NaN
# 295                        6.0                      NaN
# 296                        6.0                      NaN
# 297                        NaN                      NaN
#
#      Get CH2 Current Measurement  Sweep CH1 Voltage Setting  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                      -0.000101                        NaN
# 3                            NaN                       0.00
# 4                            NaN                       0.05
# ..                           ...                        ...
# 293                          NaN                       1.90
# 294                          NaN                       1.95
# 295                          NaN                       2.00
# 296                          NaN                       2.00
# 297                          NaN                        NaN
#
#      Get Measurement Value  Get Measurement Value.1  Set CH1 On/Off.1  \
# 0                      NaN                      NaN               NaN
# 1                      NaN                      NaN               NaN
# 2                      NaN                      NaN               NaN
# 3            -1.841447e-09                -0.000217               NaN
# 4             3.856498e-09                 0.049734               NaN
# ..                     ...                      ...               ...
# 293           9.790536e-07                 1.897827               NaN
# 294           9.855447e-07                 1.947752               NaN
# 295           9.895980e-07                 1.997742               NaN
# 296                    NaN                      NaN               0.0
# 297                    NaN                      NaN               NaN
#
#      Set CH2 On/Off ()
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 293                NaN
# 294                NaN
# 295                NaN
# 296                NaN
# 297                0.0
#
# [298 rows x 12 columns]

# %%
plt.figure()
dataset['Get Measurement Value']=dataset['Get Measurement Value'] * 1000 # to convert to mA
dataset.plot(x='Get Measurement Value.1', y='Get Measurement Value')
plt.grid()
plt.xlabel('Voltage [V]')
plt.ylabel('Current [mA]')

plt.show()

# %% [markdown]
# # Directory LVJ_PD_BVue_l1mm_02122022G2
#
# File ``Ipd_Ufpd_Uled_0_6V 2022-12-02 11-32-27 0.csv`` has only one measured value

# %%
dataset=pd.read_csv('datasets/LVJ_PD_BVue_l1mm_02122022G2/Ipd_Ufpd_Uled_0_6V 2022-12-02 11-32-27 0.csv', sep=',', skiprows=4)

print(dataset)
# Out:
#                         Time  Step  1 - Set CH1 On/Off  1 - Set CH2 On/Off  \
# 0    2022-12-02 11:23:11.040     1                 1.0                 NaN
# 1    2022-12-02 11:23:12.444     2                 NaN                 1.0
# 2    2022-12-02 11:23:17.165     3                 NaN                 NaN
# 3    2022-12-02 11:23:18.566     4                 NaN                 NaN
# 4    2022-12-02 11:23:19.957     5                 NaN                 NaN
# ..                       ...   ...                 ...                 ...
# 293  2022-12-02 11:30:25.030   294                 NaN                 NaN
# 294  2022-12-02 11:30:26.419   295                 NaN                 NaN
# 295  2022-12-02 11:30:27.806   296                 NaN                 NaN
# 296  2022-12-02 11:30:29.208   297                 NaN                 NaN
# 297  2022-12-02 11:30:30.600   298                 NaN                 NaN
#
#      1 - Sweep CH2 Voltage Setting  1 - Get CH2 Voltage Setting  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              0.0                          0.0
# 3                              0.0                          NaN
# 4                              0.0                          NaN
# ..                             ...                          ...
# 293                            6.0                          NaN
# 294                            6.0                          NaN
# 295                            6.0                          NaN
# 296                            6.0                          NaN
# 297                            NaN                          NaN
#
#      1 - Get CH2 Current Measurement  1 - Sweep CH1 Voltage Setting  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                          -0.000078                            NaN
# 3                                NaN                           0.00
# 4                                NaN                           0.05
# ..                               ...                            ...
# 293                              NaN                           1.90
# 294                              NaN                           1.95
# 295                              NaN                           2.00
# 296                              NaN                           2.00
# 297                              NaN                            NaN
#
#      Get Measurement Value  1 - Set CH1 On/Off.1  1 - Set CH2 On/Off ()
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3            -2.505323e-10                   NaN                    NaN
# 4             3.392864e-09                   NaN                    NaN
# ..                     ...                   ...                    ...
# 293           1.341915e-03                   NaN                    NaN
# 294           1.390468e-03                   NaN                    NaN
# 295           1.439064e-03                   NaN                    NaN
# 296                    NaN                   0.0                    NaN
# 297                    NaN                   NaN                    0.0
#
# [298 rows x 11 columns]

# %%
dataset=pd.read_csv('datasets/LVJ_PD_BVue_l1mm_02122022G2/Ipd_Urpd_Uled_0_6V 2022-12-02 10-29-07 0.csv', sep=',', skiprows=6)

print(dataset)
# Out:
#                         Time  Step  3 - Set CH1 On/Off  3 - Set CH2 On/Off  \
# 0    2022-12-02 10:09:41.308     1                 1.0                 NaN
# 1    2022-12-02 10:09:42.705     2                 NaN                 1.0
# 2    2022-12-02 10:09:47.450     3                 NaN                 NaN
# 3    2022-12-02 10:09:50.196     4                 NaN                 NaN
# 4    2022-12-02 10:09:52.463     5                 NaN                 NaN
# ..                       ...   ...                 ...                 ...
# 433  2022-12-02 10:26:16.368   434                 NaN                 NaN
# 434  2022-12-02 10:26:18.663   435                 NaN                 NaN
# 435  2022-12-02 10:26:20.808   436                 NaN                 NaN
# 436  2022-12-02 10:26:22.219   437                 NaN                 NaN
# 437  2022-12-02 10:26:23.634   438                 NaN                 NaN
#
#      3 - Sweep CH2 Voltage Setting  3 - Get CH2 Voltage Setting  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              0.0                          0.0
# 3                              0.0                          NaN
# 4                              0.0                          NaN
# ..                             ...                          ...
# 433                            6.0                          NaN
# 434                            6.0                          NaN
# 435                            6.0                          NaN
# 436                            6.0                          NaN
# 437                            NaN                          NaN
#
#      3 - Get CH2 Current Measurement  3 - Sweep CH1 Voltage Setting  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                          -0.000116                            NaN
# 3                                NaN                           0.00
# 4                                NaN                           0.05
# ..                               ...                            ...
# 433                              NaN                           2.90
# 434                              NaN                           2.95
# 435                              NaN                           3.00
# 436                              NaN                           3.00
# 437                              NaN                            NaN
#
#      1 - Get Measurement Value  2 - Get Measurement Value  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                -2.987787e-09                  -0.000216
# 4                 2.612333e-09                   0.049719
# ..                         ...                        ...
# 433               1.470525e-06                   2.896694
# 434               1.476742e-06                   2.946640
# 435               1.481755e-06                   2.996613
# 436                        NaN                        NaN
# 437                        NaN                        NaN
#
#      3 - Set CH1 On/Off.1  3 - Set CH2 On/Off ()
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
# ..                    ...                    ...
# 433                   NaN                    NaN
# 434                   NaN                    NaN
# 435                   NaN                    NaN
# 436                   0.0                    NaN
# 437                   NaN                    0.0
#
# [438 rows x 12 columns]

# %%
plt.figure()
#dataset['Get Measurement Value']=dataset['Get Measurement Value'] * 1000 # to convert to mA
dataset.plot(x='2 - Get Measurement Value', y='1 - Get Measurement Value')
plt.grid()
plt.xlabel('Voltage [V]')
plt.ylabel('Current [mA]')

plt.show()
